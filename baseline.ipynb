# %% [markdown]
# # Rekko challenge 2019
#
# ```
#                            /$$$$$$$  /$$$$$$$$ /$$   /$$ /$$   /$$  /$$$$$$
#                           | $$__  $$| $$_____/| $$  /$$/| $$  /$$/ /$$__  $$
#                           | $$  \ $$| $$      | $$ /$$/ | $$ /$$/ | $$  \ $$
#                           | $$$$$$$/| $$$$$   | $$$$$/  | $$$$$/  | $$  | $$
#                           | $$__  $$| $$__/   | $$  $$  | $$  $$  | $$  | $$
#                           | $$  \ $$| $$      | $$\  $$ | $$\  $$ | $$  | $$
#                           | $$  | $$| $$$$$$$$| $$ \  $$| $$ \  $$|  $$$$$$/
#                           |__/  |__/|________/|__/  \__/|__/  \__/ \______/
#
# ```

# %% [markdown]
# Добро пожаловать на соревнование по машинному обучению от онлайн-кинотеатра [Okko](http://okko.tv) Rekko Challenge 2019.
#
# В этом ноутбуке мы покажем вам пример простого но полного решения, от загрузки данных до формирования ответа. Для работы нам понадобятся библиотеки `pandas`, `numpy`, `scipy`, `implicit`, `pprint`, `tqdm`. Установить их в вашем рабочем окружении можно следующей командой.
# ```
# pip install pandas numpy scipy implicit pprint tqdm
# ```

# %%
import os
import json
import pandas as pd
import numpy as np
import tqdm

import scipy.sparse as sp

from pprint import pprint

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# Замените `DATA_PATH` на путь к данным, которые вы скачали со страницы соревнования.

# %%
DATA_PATH = './data'

# %% [markdown]
# ---

# %% [markdown]
# `catalogue.json` содержит анонимизированную метаинформацию о доступных в сервисе фильмах и сериалах.

# %%
with open(os.path.join(DATA_PATH, 'catalogue.json'), 'r') as f:
    catalogue = json.load(f)
    
catalogue = {int(k): v for k, v in catalogue.items()}

# %%
catalogue
# Out:
# {0: {u'attributes': [31115,
#    6713,
#    10906,
#    31116,
#    31117,
#    270,
#    24431,
#    42,
#    31118,
#    31119],
#   u'availability': [],
#   u'duration': 80,
#   u'feature_1': 29121982.214158818,
#   u'feature_2': 0.5752595062,
#   u'feature_3': 0,
#   u'feature_4': 1.1283323575,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  1: {u'attributes': [2786, 385, 2799, 3730, 886, 7, 11700, 42, 20, 388, 1934],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 120,
#   u'feature_1': 6610431.116079764,
#   u'feature_2': 0.7732243944,
#   u'feature_3': 3,
#   u'feature_4': 1.1120138405,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  2: {u'attributes': [31442, 31443, 31444, 31445, 113, 31446, 42, 31447],
#   u'availability': [],
#   u'duration': 80,
#   u'feature_1': 13158739.626692833,
#   u'feature_2': 0.6995015054,
#   u'feature_3': 0,
#   u'feature_4': 1.1101274384,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  3: {u'attributes': [34361, 34362, 23033, 14887, 270, 20089, 43, 25],
#   u'availability': [],
#   u'duration': 20,
#   u'feature_1': 41577117.57192578,
#   u'feature_2': 0.7029805793,
#   u'feature_3': 0,
#   u'feature_4': 1.1419293948,
#   u'feature_5': 0.6547073468,
#   u'type': u'series'},
#  4: {u'attributes': [26732,
#    26733,
#    26734,
#    9367,
#    7792,
#    336,
#    26735,
#    308,
#    54,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    26736],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 70,
#   u'feature_1': 39995792.53356842,
#   u'feature_2': 0.6265958452,
#   u'feature_3': 8,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  5: {u'attributes': [23108, 23109, 15083, 336, 23110, 123, 42, 43, 25],
#   u'availability': [],
#   u'duration': 100,
#   u'feature_1': 40485522.93847391,
#   u'feature_2': 0.6934571413,
#   u'feature_3': 0,
#   u'feature_4': 1.1352308688,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  6: {u'attributes': [9528,
#    20806,
#    20814,
#    20797,
#    20815,
#    270,
#    20816,
#    11,
#    1492,
#    13094,
#    20804,
#    14,
#    15,
#    16,
#    17,
#    18,
#    19,
#    328,
#    20,
#    20800,
#    20813,
#    12309,
#    12294,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 60,
#   u'feature_1': 5896833.393769367,
#   u'feature_2': 0.762507456,
#   u'feature_3': 14,
#   u'feature_4': 1.1212215513,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  7: {u'attributes': [20418,
#    20419,
#    20420,
#    20421,
#    20422,
#    714,
#    83,
#    7,
#    20423,
#    1492,
#    14,
#    15,
#    16,
#    17,
#    18,
#    19,
#    20,
#    1904,
#    20424,
#    20425,
#    20426,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 26408415.94223952,
#   u'feature_2': 0.7510260541,
#   u'feature_3': 12,
#   u'feature_4': 1.1352308688,
#   u'feature_5': 0.4496666915,
#   u'type': u'movie'},
#  8: {u'attributes': [172,
#    416,
#    2839,
#    5648,
#    1183,
#    7,
#    5683,
#    32,
#    11,
#    43,
#    19,
#    20,
#    5659,
#    4311,
#    197],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 110,
#   u'feature_1': 7939681.775285409,
#   u'feature_2': 0.6995015054,
#   u'feature_3': 7,
#   u'feature_4': 1.1230198714,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  9: {u'attributes': [16365,
#    18388,
#    18389,
#    18390,
#    17546,
#    3271,
#    396,
#    18391,
#    130,
#    3771,
#    18392,
#    18393,
#    14,
#    15,
#    3274,
#    3275,
#    272,
#    9722,
#    3277],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 12696999.924021399,
#   u'feature_2': 0.7764580623,
#   u'feature_3': 9,
#   u'feature_4': 0.9750563614,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  10: {u'attributes': [10511,
#    2752,
#    9076,
#    1373,
#    472,
#    7,
#    10512,
#    42,
#    43,
#    10513,
#    25],
#   u'availability': [],
#   u'duration': 100,
#   u'feature_1': 16666101.905973682,
#   u'feature_2': 0.700996701,
#   u'feature_3': 0,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  11: {u'attributes': [6730,
#    34036,
#    34037,
#    34038,
#    270,
#    34039,
#    33936,
#    34040,
#    11,
#    1492,
#    14,
#    15,
#    3273,
#    25],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 0,
#   u'feature_1': 43546894.414706424,
#   u'feature_2': 0.5356098284,
#   u'feature_3': 9,
#   u'feature_4': 1.1352308688,
#   u'feature_5': 0.0,
#   u'type': u'series'},
#  12: {u'attributes': [33482, 26930, 28504, 28141, 270, 33483, 123, 175],
#   u'availability': [],
#   u'duration': 40,
#   u'feature_1': 43155601.92000377,
#   u'feature_2': 0.7492931785,
#   u'feature_3': 0,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.6547073468,
#   u'type': u'series'},
#  13: {u'attributes': [15809,
#    18490,
#    396,
#    13456,
#    3771,
#    14,
#    15,
#    3274,
#    3275,
#    272,
#    18491,
#    3775],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 70,
#   u'feature_1': 12655023.587414904,
#   u'feature_2': 0.7654246597,
#   u'feature_3': 8,
#   u'feature_4': 1.0664757439,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  14: {u'attributes': [12896,
#    12450,
#    14522,
#    16691,
#    18487,
#    396,
#    18488,
#    3771,
#    14,
#    15,
#    3274,
#    3275,
#    272,
#    16609,
#    3775],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 12780952.597234387,
#   u'feature_2': 0.752750538,
#   u'feature_3': 8,
#   u'feature_4': 1.0618539305,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  15: {u'attributes': [1039,
#    1040,
#    1041,
#    435,
#    437,
#    247,
#    83,
#    1042,
#    42,
#    54,
#    175,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 35429548.33704649,
#   u'feature_2': 0.6468480877,
#   u'feature_3': 12,
#   u'feature_4': 1.1386044027,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  16: {u'attributes': [22532,
#    15035,
#    113,
#    27683,
#    9,
#    42,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    55,
#    27687,
#    26348,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 15029946.411544288,
#   u'feature_2': 0.7278129857,
#   u'feature_3': 8,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  17: {u'attributes': [28658, 28659, 28660, 28661, 8422, 7, 27327, 1492, 361],
#   u'availability': [],
#   u'duration': 70,
#   u'feature_1': 9101027.088065077,
#   u'feature_2': 0.6919298828,
#   u'feature_3': 1,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  18: {u'attributes': [2259,
#    26776,
#    4088,
#    747,
#    6554,
#    7,
#    51,
#    468,
#    299,
#    308,
#    54,
#    17,
#    18,
#    19,
#    20,
#    10438,
#    10439,
#    26777],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 9884585.371386299,
#   u'feature_2': 0.7440433749,
#   u'feature_3': 6,
#   u'feature_4': 1.1248043047,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  19: {u'attributes': [4166, 797, 3310, 6162, 435, 7, 6163, 42, 6164],
#   u'availability': [],
#   u'duration': 100,
#   u'feature_1': 9590751.01514084,
#   u'feature_2': 0.7561746531,
#   u'feature_3': 0,
#   u'feature_4': 1.1265750641,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  20: {u'attributes': [27341, 7, 27342, 1241, 25],
#   u'availability': [],
#   u'duration': 50,
#   u'feature_1': 21370088.73038134,
#   u'feature_2': 0.717517505,
#   u'feature_3': 0,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  21: {u'attributes': [10580,
#    10581,
#    10582,
#    2157,
#    4171,
#    7,
#    10583,
#    10,
#    42,
#    11,
#    43,
#    14,
#    15,
#    19,
#    20,
#    21,
#    10584,
#    8559],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 26665882.46685285,
#   u'feature_2': 0.5503366264,
#   u'feature_3': 9,
#   u'feature_4': 1.1283323575,
#   u'feature_5': 0.4496666915,
#   u'type': u'movie'},
#  22: {u'attributes': [19257, 19258, 2689, 51, 19259, 85, 42, 19260],
#   u'availability': [],
#   u'duration': 30,
#   u'feature_1': 12543086.689797588,
#   u'feature_2': 0.7208257393,
#   u'feature_3': 0,
#   u'feature_4': 1.1004572841,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  23: {u'attributes': [29236, 29237, 29238, 29239, 7, 29240, 42, 29241],
#   u'availability': [],
#   u'duration': 70,
#   u'feature_1': 13256684.412107985,
#   u'feature_2': 0.6259823993,
#   u'feature_3': 0,
#   u'feature_4': 1.1157410659,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  24: {u'attributes': [35799,
#    35800,
#    35801,
#    35802,
#    7,
#    35803,
#    35804,
#    35805,
#    1134,
#    15,
#    202,
#    33385,
#    25],
#   u'availability': [u'subscription'],
#   u'duration': 20,
#   u'feature_1': 34898400.95613111,
#   u'feature_2': 0.7536096584,
#   u'feature_3': 8,
#   u'feature_4': 1.1352308688,
#   u'feature_5': -1,
#   u'type': u'series'},
#  25: {u'attributes': [31378, 270, 31127, 1134, 14, 15, 1135, 239, 20],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 40,
#   u'feature_1': 41965218.76381529,
#   u'feature_2': 0.6380549192,
#   u'feature_3': 8,
#   u'feature_4': 1.1283323575,
#   u'feature_5': -1,
#   u'type': u'movie'},
#  26: {u'attributes': [762,
#    9343,
#    772,
#    1249,
#    7,
#    1320,
#    1321,
#    31,
#    32,
#    10,
#    43,
#    14,
#    15,
#    131,
#    170,
#    33,
#    17,
#    21,
#    35,
#    36,
#    22,
#    24,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 120,
#   u'feature_1': 38540578.53204576,
#   u'feature_2': 0.7208257393,
#   u'feature_3': 37,
#   u'feature_4': 1.140272879,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  27: {u'attributes': [5043,
#    9735,
#    638,
#    21960,
#    396,
#    17340,
#    16679,
#    1492,
#    14,
#    15,
#    3273,
#    16,
#    3275,
#    6478],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 20,
#   u'feature_1': 36000763.362040415,
#   u'feature_2': 0.7662537759,
#   u'feature_3': 11,
#   u'feature_4': 1.0398293713,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  28: {u'attributes': [14929,
#    18366,
#    34110,
#    12428,
#    270,
#    34600,
#    130,
#    42,
#    14,
#    15,
#    32811,
#    25],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 50,
#   u'feature_1': 40359592.63308848,
#   u'feature_2': 0.7703706452,
#   u'feature_3': 10,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.6547073468,
#   u'type': u'series'},
#  29: {u'attributes': [10017,
#    10021,
#    10022,
#    10023,
#    52,
#    10024,
#    10025,
#    1134,
#    124,
#    14,
#    15,
#    1135,
#    239,
#    4133,
#    71,
#    25],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 50,
#   u'feature_1': 41689065.15796214,
#   u'feature_2': 0.7337596467,
#   u'feature_3': 18,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  30: {u'attributes': [6730,
#    395,
#    21889,
#    396,
#    21862,
#    1492,
#    14,
#    15,
#    3273,
#    16,
#    9732,
#    6479,
#    3277],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 10,
#   u'feature_1': 36000763.362040415,
#   u'feature_2': 0.827014415,
#   u'feature_3': 12,
#   u'feature_4': 1.0732396307,
#   u'feature_5': 0.4496666915,
#   u'type': u'movie'},
#  31: {u'attributes': [584,
#    6085,
#    6086,
#    6087,
#    83,
#    6088,
#    43,
#    14,
#    15,
#    131,
#    17,
#    18,
#    19,
#    21,
#    55,
#    361,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 40933883.65552648,
#   u'feature_2': 0.6615934043,
#   u'feature_3': 15,
#   u'feature_4': 1.140272879,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  32: {u'attributes': [31363, 270, 31127, 1134, 14, 15, 1135, 239, 20],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 40,
#   u'feature_1': 41965218.76381529,
#   u'feature_2': 0.6380549192,
#   u'feature_3': 10,
#   u'feature_4': 1.1283323575,
#   u'feature_5': -1,
#   u'type': u'movie'},
#  33: {u'attributes': [12447,
#    12896,
#    12891,
#    9749,
#    12897,
#    396,
#    12892,
#    3771,
#    14,
#    15,
#    3274,
#    328,
#    272,
#    6479,
#    12898,
#    10325,
#    4861],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 26647317.978540547,
#   u'feature_2': 0.7848093215,
#   u'feature_3': 18,
#   u'feature_4': 1.0547431243,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  34: {u'attributes': [318,
#    215,
#    10586,
#    10874,
#    850,
#    192,
#    7,
#    22010,
#    42,
#    11,
#    19,
#    20,
#    2370,
#    22011,
#    188],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 110,
#   u'feature_1': 6190667.750014825,
#   u'feature_2': 0.7707797265,
#   u'feature_3': 4,
#   u'feature_4': 1.0984737271,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  35: {u'attributes': [3136,
#    3203,
#    3204,
#    3205,
#    3206,
#    7,
#    1541,
#    43,
#    17,
#    18,
#    19,
#    20,
#    3207,
#    3208,
#    689],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 80,
#   u'feature_1': 6904265.472325223,
#   u'feature_2': 0.7259630842,
#   u'feature_3': 6,
#   u'feature_4': 1.1082255103,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  36: {u'attributes': [9715,
#    3764,
#    17331,
#    18843,
#    21713,
#    21262,
#    21714,
#    21715,
#    21716,
#    21717,
#    16377,
#    396,
#    21442,
#    43,
#    839,
#    16379,
#    21718,
#    644],
#   u'availability': [],
#   u'duration': 80,
#   u'feature_1': 4819440.754202686,
#   u'feature_2': 0.7879399371,
#   u'feature_3': 0,
#   u'feature_4': 1.0067612037,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  37: {u'attributes': [30928, 342, 30929, 42, 30930],
#   u'availability': [],
#   u'duration': 90,
#   u'feature_1': 11311780.816007094,
#   u'feature_2': 0.6929487826,
#   u'feature_3': 0,
#   u'feature_4': 1.1138849678,
#   u'feature_5': -1,
#   u'type': u'movie'},
#  38: {u'attributes': [24085,
#    24086,
#    24087,
#    24088,
#    83,
#    52,
#    24089,
#    24090,
#    1134,
#    14,
#    15,
#    1135,
#    18,
#    19,
#    20,
#    34,
#    1904,
#    36,
#    24091,
#    24092,
#    24093],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 40,
#   u'feature_1': 8821184.844021782,
#   u'feature_2': 0.738267368,
#   u'feature_3': 13,
#   u'feature_4': 1.1283323575,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  39: {u'attributes': [28013, 28014, 28015, 5909, 28016, 42, 28017],
#   u'availability': [],
#   u'duration': 90,
#   u'feature_1': 19113731.728970792,
#   u'feature_2': 0.7305699432,
#   u'feature_3': 0,
#   u'feature_4': 1.1230198714,
#   u'feature_5': -1,
#   u'type': u'movie'},
#  40: {u'attributes': [690,
#    612,
#    691,
#    692,
#    693,
#    7,
#    694,
#    42,
#    54,
#    175,
#    170,
#    33,
#    17,
#    20,
#    695,
#    696,
#    489,
#    25],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 130,
#   u'feature_1': 19156072.11960773,
#   u'feature_2': 0.7707797265,
#   u'feature_3': 5,
#   u'feature_4': 1.1082255103,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  41: {u'attributes': [27449,
#    30557,
#    30558,
#    30559,
#    30560,
#    113,
#    30561,
#    43,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    30562,
#    30563,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 33391334.51880593,
#   u'feature_2': 0.7217653315,
#   u'feature_3': 10,
#   u'feature_4': 1.1386044027,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  42: {u'attributes': [21351,
#    12896,
#    12405,
#    16691,
#    18487,
#    396,
#    18488,
#    3771,
#    14,
#    15,
#    3274,
#    3275,
#    272,
#    16608,
#    16609],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 60,
#   u'feature_1': 13046802.729075516,
#   u'feature_2': 0.7695510701,
#   u'feature_3': 7,
#   u'feature_4': 1.0571377879,
#   u'feature_5': 0.0,
#   u'type': u'multipart_movie'},
#  43: {u'attributes': [17398,
#    25326,
#    1513,
#    435,
#    1374,
#    7,
#    6241,
#    31,
#    54,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    6242,
#    6243,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 30883707.522749543,
#   u'feature_2': 0.7254991034,
#   u'feature_3': 15,
#   u'feature_4': 1.1369237919,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  44: {u'attributes': [172,
#    5684,
#    3455,
#    658,
#    2335,
#    7,
#    51,
#    627,
#    31,
#    32,
#    308,
#    42,
#    17,
#    18,
#    20,
#    388,
#    5685,
#    5686,
#    370,
#    197],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 110,
#   u'feature_1': 6316596.759834306,
#   u'feature_2': 0.7752488753,
#   u'feature_3': 9,
#   u'feature_4': 1.1194091265,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  45: {u'attributes': [11175,
#    11176,
#    11177,
#    11178,
#    7,
#    11173,
#    32,
#    10,
#    11,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    5897,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 34706669.01836291,
#   u'feature_2': 0.695988106,
#   u'feature_3': 12,
#   u'feature_4': 1.1352308688,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  46: {u'attributes': [10514,
#    4000,
#    26114,
#    24883,
#    13636,
#    7,
#    26115,
#    42,
#    43,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    55,
#    26116,
#    26117,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 27846437.29783951,
#   u'feature_2': 0.6815772575,
#   u'feature_3': 9,
#   u'feature_4': 1.1352308688,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  47: {u'attributes': [5795,
#    8583,
#    14005,
#    14006,
#    8931,
#    52,
#    14007,
#    31,
#    14,
#    15,
#    19,
#    20,
#    21,
#    14008,
#    14009],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 8821184.844021782,
#   u'feature_2': 0.6736103652,
#   u'feature_3': 7,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  48: {u'attributes': [9689,
#    10868,
#    10889,
#    10902,
#    336,
#    10892,
#    42,
#    43,
#    14,
#    15,
#    19,
#    20,
#    55,
#    10893,
#    361,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 16415839.051904062,
#   u'feature_2': 0.7198836614,
#   u'feature_3': 7,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  49: {u'attributes': [4107, 13590, 3485, 7, 13591, 308, 54, 13592],
#   u'availability': [],
#   u'duration': 90,
#   u'feature_1': 26293089.520219523,
#   u'feature_2': 0.6398310088,
#   u'feature_3': 0,
#   u'feature_4': 1.1194091265,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  50: {u'attributes': [17580,
#    17581,
#    4389,
#    17582,
#    10421,
#    270,
#    83,
#    12698,
#    42,
#    43,
#    14,
#    15,
#    17,
#    18,
#    19,
#    272,
#    20,
#    15868,
#    361,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 40300766.81358891,
#   u'feature_2': 0.6944716868,
#   u'feature_3': 13,
#   u'feature_4': 1.1194091265,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  51: {u'attributes': [15093,
#    1815,
#    1950,
#    30779,
#    7,
#    30780,
#    30781,
#    1492,
#    131,
#    170,
#    33,
#    17,
#    24,
#    25],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 60,
#   u'feature_1': 39911840.5081384,
#   u'feature_2': 0.7241035226,
#   u'feature_3': 13,
#   u'feature_4': 1.140272879,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  52: {u'attributes': [3582,
#    3583,
#    3584,
#    3585,
#    3586,
#    3587,
#    7,
#    3588,
#    11,
#    43,
#    3589,
#    3590,
#    3591,
#    3592,
#    19,
#    20,
#    3593,
#    3594,
#    3595],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 80,
#   u'feature_1': 5980786.066982354,
#   u'feature_2': 0.7319404589,
#   u'feature_3': 4,
#   u'feature_4': 1.0964729963,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  53: {u'attributes': [32432, 32433, 32434, 32435, 7, 32436, 31, 42, 54, 25],
#   u'availability': [],
#   u'duration': 100,
#   u'feature_1': 42178345.51564761,
#   u'feature_2': 0.6929487826,
#   u'feature_3': 0,
#   u'feature_4': 1.1352308688,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  54: {u'attributes': [9306,
#    62,
#    17736,
#    5762,
#    7386,
#    83,
#    9361,
#    42,
#    54,
#    22997,
#    361],
#   u'availability': [],
#   u'duration': 110,
#   u'feature_1': 13046802.729075516,
#   u'feature_2': 0.7074043036,
#   u'feature_3': 0,
#   u'feature_4': 1.1265750641,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  55: {u'attributes': [32718,
#    14890,
#    32719,
#    18674,
#    22799,
#    396,
#    3954,
#    130,
#    3771,
#    138,
#    14,
#    15,
#    3274,
#    3275,
#    272,
#    18383,
#    3955],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 7757784.316657268,
#   u'feature_2': 0.7945024956,
#   u'feature_3': 16,
#   u'feature_4': 1.04987804,
#   u'feature_5': 0.5927161087,
#   u'type': u'multipart_movie'},
#  56: {u'attributes': [6514, 20554, 6632, 20555, 714, 20556, 42, 20557, 25],
#   u'availability': [],
#   u'duration': 120,
#   u'feature_1': 18638631.826386694,
#   u'feature_2': 0.7291941325,
#   u'feature_3': 0,
#   u'feature_4': 1.1283323575,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  57: {u'attributes': [2270,
#    13921,
#    13245,
#    3028,
#    10270,
#    7,
#    11746,
#    13922,
#    11,
#    1492,
#    14,
#    15,
#    16,
#    33,
#    20,
#    388,
#    34,
#    35,
#    36,
#    13923,
#    13924,
#    13925,
#    188,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 20182795.013133608,
#   u'feature_2': 0.7156131944,
#   u'feature_3': 17,
#   u'feature_4': 1.1335254517,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  58: {u'attributes': [29338, 7, 29339, 1241, 25],
#   u'availability': [],
#   u'duration': 20,
#   u'feature_1': 21384213.1522556,
#   u'feature_2': 0.717517505,
#   u'feature_3': 0,
#   u'feature_4': 1.1265750641,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  59: {u'attributes': [11588,
#    11589,
#    11590,
#    11591,
#    6672,
#    2228,
#    83,
#    571,
#    11592,
#    1492,
#    11593,
#    361],
#   u'availability': [],
#   u'duration': 70,
#   u'feature_1': 7254068.27737934,
#   u'feature_2': 0.7484235682,
#   u'feature_3': 1,
#   u'feature_4': 1.1063077983,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  60: {u'attributes': [13223,
#    13224,
#    13225,
#    2285,
#    13226,
#    83,
#    13227,
#    42,
#    43,
#    14,
#    15,
#    17,
#    18,
#    19,
#    272,
#    20,
#    13228,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 110,
#   u'feature_1': 32146121.230436902,
#   u'feature_2': 0.6969954765,
#   u'feature_3': 9,
#   u'feature_4': 1.1369237919,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  61: {u'attributes': [4622,
#    5007,
#    2824,
#    7334,
#    4615,
#    7,
#    7335,
#    31,
#    43,
#    19,
#    20,
#    3469,
#    7336,
#    7337,
#    188],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 80,
#   u'feature_1': 6568454.779473271,
#   u'feature_2': 0.7146572067,
#   u'feature_3': 4,
#   u'feature_4': 1.0819607777,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  62: {u'attributes': [13446,
#    13447,
#    13448,
#    270,
#    13449,
#    42,
#    14,
#    15,
#    19,
#    272,
#    20,
#    13450],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 27131116.31087699,
#   u'feature_2': 0.7650093766,
#   u'feature_3': 9,
#   u'feature_4': 1.1212215513,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  63: {u'attributes': [8645,
#    1950,
#    1054,
#    416,
#    10633,
#    10634,
#    7,
#    10635,
#    43,
#    9648,
#    10636,
#    10637,
#    10638,
#    17,
#    18,
#    19,
#    20,
#    8647,
#    10639,
#    1515,
#    171,
#    25],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 4609559.071170216,
#   u'feature_2': 0.7141782487,
#   u'feature_3': 4,
#   u'feature_4': 1.1265750641,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  64: {u'attributes': [11959,
#    4803,
#    4128,
#    3662,
#    6399,
#    270,
#    30101,
#    42,
#    138,
#    124,
#    14,
#    15,
#    17,
#    18,
#    19,
#    328,
#    272,
#    20,
#    27950,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 19049441.86009968,
#   u'feature_2': 0.6197891088,
#   u'feature_3': 16,
#   u'feature_4': 1.1335254517,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  65: {u'attributes': [11621,
#    191,
#    5443,
#    33740,
#    192,
#    437,
#    7,
#    33666,
#    130,
#    42,
#    2328],
#   u'availability': [u'purchase'],
#   u'duration': 50,
#   u'feature_1': 16484857.412581643,
#   u'feature_2': 0.7871598596,
#   u'feature_3': 4,
#   u'feature_4': 1.1230198714,
#   u'feature_5': 0.6547073468,
#   u'type': u'series'},
#  66: {u'attributes': [11304,
#    23168,
#    32645,
#    34537,
#    34538,
#    7,
#    16151,
#    34285,
#    33877,
#    123,
#    42,
#    34539,
#    34540,
#    34541,
#    34004,
#    25],
#   u'availability': [],
#   u'duration': 40,
#   u'feature_1': 28517762.97061655,
#   u'feature_2': 0.7548944652,
#   u'feature_3': 0,
#   u'feature_4': 1.1335254517,
#   u'feature_5': 0.6547073468,
#   u'type': u'series'},
#  67: {u'attributes': [11055,
#    7723,
#    26346,
#    113,
#    83,
#    26347,
#    42,
#    43,
#    26348,
#    26349,
#    361,
#    25],
#   u'availability': [],
#   u'duration': 100,
#   u'feature_1': 15719319.641821716,
#   u'feature_2': 0.7264264613,
#   u'feature_3': 0,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  68: {u'attributes': [1211,
#    1478,
#    1479,
#    1480,
#    1481,
#    1482,
#    1483,
#    7,
#    76,
#    85,
#    42,
#    43,
#    1484,
#    1485,
#    1486,
#    17,
#    18,
#    19,
#    20,
#    78,
#    1487],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 110,
#   u'feature_1': 4231772.04171177,
#   u'feature_2': 0.7510260541,
#   u'feature_3': 8,
#   u'feature_4': 1.1082255103,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  69: {u'attributes': [32287,
#    32288,
#    9920,
#    1390,
#    7,
#    32289,
#    31,
#    42,
#    54,
#    14,
#    15,
#    19,
#    20,
#    21,
#    32290,
#    32291],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 37906990.58994157,
#   u'feature_2': 0.5276071269,
#   u'feature_3': 8,
#   u'feature_4': 1.1230198714,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  70: {u'attributes': [17103,
#    214,
#    1107,
#    17104,
#    7,
#    5614,
#    17105,
#    54,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 37906990.58994157,
#   u'feature_2': 0.6191638141,
#   u'feature_3': 8,
#   u'feature_4': 1.140272879,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  71: {u'attributes': [5170,
#    10389,
#    679,
#    2207,
#    1374,
#    7,
#    7184,
#    10390,
#    11,
#    1492,
#    14,
#    15,
#    16,
#    33,
#    20,
#    388,
#    34,
#    35,
#    36,
#    22,
#    7186,
#    10391,
#    10392,
#    1704,
#    1705,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 110,
#   u'feature_1': 8079602.897307056,
#   u'feature_2': 0.7360206399,
#   u'feature_3': 37,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  72: {u'attributes': [1763,
#    2046,
#    2047,
#    2048,
#    7,
#    2049,
#    2050,
#    2051,
#    1225,
#    11,
#    1492,
#    14,
#    15,
#    16,
#    33,
#    17,
#    20,
#    388,
#    35,
#    36,
#    24,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 35644258.59435465,
#   u'feature_2': 0.761669561,
#   u'feature_3': 43,
#   u'feature_4': 1.1386044027,
#   u'feature_5': 0.4496666915,
#   u'type': u'movie'},
#  73: {u'attributes': [34759,
#    8155,
#    4804,
#    14873,
#    270,
#    34760,
#    123,
#    14,
#    15,
#    32811,
#    56,
#    25],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 50,
#   u'feature_1': 40269838.9014126,
#   u'feature_2': 0.6878248779,
#   u'feature_3': 10,
#   u'feature_4': 1.1335254517,
#   u'feature_5': 0.6547073468,
#   u'type': u'series'},
#  74: {u'attributes': [18020,
#    20814,
#    27843,
#    27844,
#    27845,
#    270,
#    51,
#    27846,
#    42,
#    27847,
#    27848],
#   u'availability': [],
#   u'duration': 100,
#   u'feature_1': 29134026.604908954,
#   u'feature_2': 0.7413891621,
#   u'feature_3': 0,
#   u'feature_4': 1.1212215513,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  75: {u'attributes': [25458,
#    25459,
#    952,
#    1119,
#    1233,
#    7,
#    25460,
#    32,
#    10,
#    11,
#    43,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    2936,
#    2937],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 23761850.187039014,
#   u'feature_2': 0.66601027,
#   u'feature_3': 9,
#   u'feature_4': 1.1283323575,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  76: {u'attributes': [29765,
#    29766,
#    29767,
#    29768,
#    19366,
#    577,
#    29769,
#    15130,
#    32,
#    42,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    29770,
#    15136,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 18612758.56474342,
#   u'feature_2': 0.6841937662,
#   u'feature_3': 9,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  77: {u'attributes': [9392,
#    9393,
#    14844,
#    585,
#    3761,
#    83,
#    26158,
#    31,
#    54,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    26159,
#    26160,
#    361,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 130,
#   u'feature_1': 26982958.95225375,
#   u'feature_2': 0.737370377,
#   u'feature_3': 9,
#   u'feature_4': 1.1352308688,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  78: {u'attributes': [3301,
#    937,
#    12357,
#    5208,
#    18094,
#    22752,
#    7,
#    22753,
#    42,
#    54,
#    5978,
#    8979,
#    19,
#    20,
#    1709,
#    709,
#    489],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 120,
#   u'feature_1': 1601254.9477048104,
#   u'feature_2': 0.7484235682,
#   u'feature_3': 2,
#   u'feature_4': 1.0595078904,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  79: {u'attributes': [222,
#    2449,
#    210,
#    2158,
#    1234,
#    7,
#    2633,
#    31,
#    32,
#    10,
#    33,
#    19,
#    20,
#    34,
#    35,
#    36,
#    2634,
#    2635,
#    24,
#    25],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 130,
#   u'feature_1': 10710119.991314014,
#   u'feature_2': 0.737370377,
#   u'feature_3': 13,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  80: {u'attributes': [33630,
#    4389,
#    20260,
#    12181,
#    270,
#    35249,
#    4393,
#    42,
#    124,
#    14,
#    15,
#    32811,
#    25],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 50,
#   u'feature_1': 39366129.34654778,
#   u'feature_2': 0.7314842061,
#   u'feature_3': 16,
#   u'feature_4': 1.140272879,
#   u'feature_5': 0.6804096966,
#   u'type': u'series'},
#  81: {u'attributes': [398,
#    2556,
#    1626,
#    10228,
#    798,
#    342,
#    7,
#    2557,
#    10,
#    54,
#    20,
#    388,
#    2414,
#    17090,
#    197],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 120,
#   u'feature_1': 6358573.0964408,
#   u'feature_2': 0.7227024511,
#   u'feature_3': 3,
#   u'feature_4': 1.1101274384,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  82: {u'attributes': [28502,
#    28503,
#    12711,
#    10044,
#    1016,
#    270,
#    16232,
#    42,
#    43,
#    14,
#    15,
#    19,
#    272,
#    20,
#    44,
#    27559],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 9059050.751458582,
#   u'feature_2': 0.7687296044,
#   u'feature_3': 16,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  83: {u'attributes': [13139,
#    13140,
#    13141,
#    1678,
#    3073,
#    1975,
#    4189,
#    3654,
#    6154,
#    13142,
#    7,
#    3467,
#    10,
#    43,
#    19,
#    20,
#    1539,
#    1540,
#    188],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 90,
#   u'feature_1': 3196355.7387515837,
#   u'feature_2': 0.6681983275,
#   u'feature_3': 4,
#   u'feature_4': 1.1265750641,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  84: {u'attributes': [34332, 34333, 10280, 34334, 270, 34249, 43, 25],
#   u'availability': [],
#   u'duration': 20,
#   u'feature_1': 41577117.57192578,
#   u'feature_2': 0.7314842061,
#   u'feature_3': 0,
#   u'feature_4': 1.140272879,
#   u'feature_5': 0.6547073468,
#   u'type': u'series'},
#  85: {u'attributes': [4431,
#    456,
#    11523,
#    2091,
#    693,
#    7,
#    13558,
#    42,
#    1225,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    55,
#    13559,
#    13560,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 27846437.29783951,
#   u'feature_2': 0.7466779508,
#   u'feature_3': 8,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  86: {u'attributes': [17436,
#    12658,
#    15599,
#    13112,
#    270,
#    20753,
#    175,
#    14,
#    15,
#    328,
#    32811,
#    25],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 50,
#   u'feature_1': 38356325.896476,
#   u'feature_2': 0.7268892362,
#   u'feature_3': 13,
#   u'feature_4': 1.1335254517,
#   u'feature_5': 0.6547073468,
#   u'type': u'series'},
#  87: {u'attributes': [13964,
#    13965,
#    13966,
#    1652,
#    13967,
#    7,
#    1639,
#    31,
#    54,
#    20,
#    388,
#    13968,
#    4558,
#    197],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 80,
#   u'feature_1': 6904265.472325223,
#   u'feature_2': 0.7378191549,
#   u'feature_3': 3,
#   u'feature_4': 1.0819607777,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  88: {u'attributes': [15898, 7, 15899, 42, 138, 910, 15900, 15901, 15902],
#   u'availability': [u'purchase'],
#   u'duration': 200,
#   u'feature_1': 11479686.162433071,
#   u'feature_2': 0.7728181135,
#   u'feature_3': 3,
#   u'feature_4': 0.8405842039,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  89: {u'attributes': [5377,
#    6165,
#    519,
#    8861,
#    2461,
#    7,
#    8862,
#    31,
#    32,
#    10,
#    33,
#    17,
#    20,
#    388,
#    35,
#    36,
#    8863,
#    3457,
#    8864,
#    25],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 120,
#   u'feature_1': 33657184.002864085,
#   u'feature_2': 0.7662537759,
#   u'feature_3': 14,
#   u'feature_4': 1.1386044027,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  90: {u'attributes': [9675,
#    9698,
#    9699,
#    9700,
#    270,
#    9701,
#    42,
#    138,
#    14,
#    15,
#    131,
#    17,
#    18,
#    19,
#    272,
#    56,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 42668361.91673538,
#   u'feature_2': 0.65768319,
#   u'feature_3': 21,
#   u'feature_4': 1.1419293948,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  91: {u'attributes': [12584, 15809, 12450, 18447, 396, 18448, 3771, 4861, 25],
#   u'availability': [],
#   u'duration': 80,
#   u'feature_1': 34549740.35440294,
#   u'feature_2': 0.7863780695,
#   u'feature_3': 2,
#   u'feature_4': 1.0798111532,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  92: {u'attributes': [33702, 270, 33703, 1134, 14, 15, 1135],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 40,
#   u'feature_1': 41773020.58425277,
#   u'feature_2': 0.6929487826,
#   u'feature_3': 8,
#   u'feature_4': 1.1369237919,
#   u'feature_5': 0.5927161087,
#   u'type': u'series'},
#  93: {u'attributes': [19201,
#    19280,
#    11938,
#    19386,
#    19331,
#    368,
#    11942,
#    85,
#    42,
#    43,
#    16132,
#    19283,
#    16134,
#    19285],
#   u'availability': [],
#   u'duration': 70,
#   u'feature_1': 5491062.139906591,
#   u'feature_2': 0.7514579586,
#   u'feature_3': 0,
#   u'feature_4': 1.0819607777,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  94: {u'attributes': [8890,
#    2311,
#    22437,
#    33282,
#    33283,
#    2468,
#    33284,
#    33285,
#    33286,
#    3539,
#    33287,
#    7,
#    33288,
#    9,
#    10,
#    33289,
#    33290,
#    33291,
#    33292,
#    19,
#    32602,
#    32603,
#    20,
#    32552,
#    32553,
#    33293,
#    33294,
#    33295,
#    33296],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 80,
#   u'feature_1': 7477942.072613975,
#   u'feature_2': 0.7492931785,
#   u'feature_3': 2,
#   u'feature_4': 1.1230198714,
#   u'feature_5': 0.5927161087,
#   u'type': u'multipart_movie'},
#  95: {u'attributes': [309,
#    6453,
#    1239,
#    1529,
#    2681,
#    437,
#    83,
#    52,
#    6095,
#    123,
#    42,
#    43,
#    17,
#    18,
#    19,
#    20,
#    4085,
#    6454,
#    2854,
#    171,
#    25],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 90,
#   u'feature_1': 34244852.715355,
#   u'feature_2': 0.761249873,
#   u'feature_3': 13,
#   u'feature_4': 1.1120138405,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  96: {u'attributes': [3933,
#    8269,
#    8270,
#    8271,
#    8272,
#    7,
#    8273,
#    8274,
#    31,
#    32,
#    308,
#    54,
#    17,
#    18,
#    19,
#    20,
#    5917,
#    2489,
#    8275,
#    165],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 90,
#   u'feature_1': 9212963.985682394,
#   u'feature_2': 0.6445243912,
#   u'feature_3': 5,
#   u'feature_4': 1.1230198714,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  97: {u'attributes': [30729,
#    30730,
#    30731,
#    30732,
#    30733,
#    7,
#    52,
#    30734,
#    1134,
#    42,
#    71],
#   u'availability': [],
#   u'duration': 90,
#   u'feature_1': 19046849.594590187,
#   u'feature_2': 0.7720041583,
#   u'feature_3': 0,
#   u'feature_4': 1.1212215513,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  98: {u'attributes': [17529,
#    16400,
#    17224,
#    17214,
#    396,
#    16759,
#    3771,
#    910,
#    16760,
#    12196,
#    16583,
#    3277],
#   u'availability': [u'purchase'],
#   u'duration': 90,
#   u'feature_1': 11479686.162433071,
#   u'feature_2': 0.6934571413,
#   u'feature_3': 5,
#   u'feature_4': 0.946133291,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  99: {u'attributes': [18559,
#    18061,
#    18560,
#    396,
#    17829,
#    18561,
#    3771,
#    18562,
#    14,
#    15,
#    3273,
#    16,
#    3274,
#    3275,
#    272,
#    18563,
#    18564,
#    18565,
#    5048],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 0,
#   u'feature_1': 32971571.31468673,
#   u'feature_2': 0.7891068586,
#   u'feature_3': 15,
#   u'feature_4': 1.0819607777,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  100: {u'attributes': [18441,
#    16300,
#    16580,
#    18770,
#    18771,
#    18643,
#    396,
#    18772,
#    3771,
#    18773,
#    910,
#    18774,
#    16364,
#    3277],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 80,
#   u'feature_1': 6064738.740195342,
#   u'feature_2': 0.752750538,
#   u'feature_3': 4,
#   u'feature_4': 0.9537104605,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  101: {u'attributes': [7318,
#    11085,
#    4001,
#    11799,
#    11800,
#    7,
#    33926,
#    34177,
#    34178,
#    11,
#    43,
#    11803,
#    34179,
#    34180],
#   u'availability': [u'purchase'],
#   u'duration': 20,
#   u'feature_1': 33433310.855412424,
#   u'feature_2': 0.576672624,
#   u'feature_3': 3,
#   u'feature_4': 1.1212215513,
#   u'feature_5': 0.4496666915,
#   u'type': u'series'},
#  102: {u'attributes': [14277,
#    14278,
#    2236,
#    3599,
#    2707,
#    7,
#    14279,
#    2633,
#    11,
#    1492,
#    14,
#    15,
#    16,
#    170,
#    33,
#    20,
#    34,
#    35,
#    36,
#    22,
#    14280,
#    2635,
#    2714,
#    1704,
#    1705,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 33992994.69571604,
#   u'feature_2': 0.7582981253,
#   u'feature_3': 37,
#   u'feature_4': 1.1386044027,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  103: {u'attributes': [1875,
#    1449,
#    1879,
#    1880,
#    1881,
#    7,
#    1882,
#    31,
#    32,
#    10,
#    54,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    1883],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 6204659.8622169895,
#   u'feature_2': 0.4900876962,
#   u'feature_3': 15,
#   u'feature_4': 1.1175823742,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  104: {u'attributes': [9506,
#    28484,
#    28485,
#    10431,
#    10209,
#    83,
#    336,
#    10863,
#    32,
#    42,
#    10864,
#    25],
#   u'availability': [],
#   u'duration': 100,
#   u'feature_1': 16370893.116206698,
#   u'feature_2': 0.7548944652,
#   u'feature_3': 0,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  105: {u'attributes': [173,
#    4718,
#    4719,
#    4720,
#    217,
#    7,
#    4721,
#    31,
#    10,
#    42,
#    11,
#    43,
#    19,
#    20,
#    4715,
#    4722,
#    4723,
#    24],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 6680391.677090588,
#   u'feature_2': 0.7151355214,
#   u'feature_3': 5,
#   u'feature_4': 1.1004572841,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  106: {u'attributes': [1211,
#    1488,
#    1489,
#    375,
#    1490,
#    7,
#    1491,
#    8,
#    11,
#    1492,
#    14,
#    15,
#    16,
#    33,
#    20,
#    388,
#    21,
#    34,
#    35,
#    36,
#    1253,
#    1493,
#    1255,
#    1494,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 14264116.490663841,
#   u'feature_2': 0.7816509395,
#   u'feature_3': 24,
#   u'feature_4': 1.1120138405,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  107: {u'attributes': [118,
#    746,
#    19923,
#    8069,
#    1139,
#    7,
#    17505,
#    85,
#    31,
#    43,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    55,
#    10663,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 16384715.18537863,
#   u'feature_2': 0.7217653315,
#   u'feature_3': 11,
#   u'feature_4': 1.1283323575,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  108: {u'attributes': [4569,
#    5455,
#    5456,
#    5457,
#    7,
#    5458,
#    42,
#    54,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 35588178.726874754,
#   u'feature_2': 0.7250345172,
#   u'feature_3': 11,
#   u'feature_4': 1.1369237919,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  109: {u'attributes': [24757, 24789, 17120, 6781, 270, 24758, 42, 43, 25],
#   u'availability': [],
#   u'duration': 110,
#   u'feature_1': 100.6247816839,
#   u'feature_2': 0.7222341996,
#   u'feature_3': 1,
#   u'feature_4': 1.1194091265,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  110: {u'attributes': [19745,
#    19746,
#    19747,
#    19748,
#    19749,
#    7,
#    2391,
#    85,
#    42,
#    14,
#    15,
#    19,
#    20,
#    55,
#    19750],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 70,
#   u'feature_1': 8611303.160989312,
#   u'feature_2': 0.6873084091,
#   u'feature_3': 7,
#   u'feature_4': 1.1194091265,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  111: {u'attributes': [29164,
#    29165,
#    29166,
#    17442,
#    113,
#    17443,
#    1492,
#    17445,
#    489],
#   u'availability': [],
#   u'duration': 80,
#   u'feature_1': 13746408.33918375,
#   u'feature_2': 0.5571054618,
#   u'feature_3': 1,
#   u'feature_4': 1.1283323575,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  112: {u'attributes': [6920,
#    6947,
#    6948,
#    6949,
#    6950,
#    7,
#    6917,
#    6388,
#    43,
#    910,
#    6951,
#    961],
#   u'availability': [u'purchase'],
#   u'duration': 90,
#   u'feature_1': 11479686.162433071,
#   u'feature_2': 0.7409448636,
#   u'feature_3': 3,
#   u'feature_4': 0.9342802843,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  113: {u'attributes': [27149,
#    27150,
#    27151,
#    27152,
#    7,
#    27153,
#    308,
#    42,
#    54,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    27154,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 13746408.33918375,
#   u'feature_2': 0.5898247493,
#   u'feature_3': 9,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  114: {u'attributes': [27392,
#    13142,
#    550,
#    2825,
#    2216,
#    7,
#    27393,
#    10,
#    43,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    27394,
#    27395,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 21466525.80092841,
#   u'feature_2': 0.5316309576,
#   u'feature_3': 9,
#   u'feature_4': 1.1335254517,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  115: {u'attributes': [22545,
#    22249,
#    14811,
#    376,
#    83,
#    22546,
#    10,
#    43,
#    14,
#    15,
#    239,
#    17,
#    20,
#    21,
#    700,
#    22547,
#    22548,
#    361],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 12403165.56777594,
#   u'feature_2': 0.7203550119,
#   u'feature_3': 10,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  116: {u'attributes': [17067,
#    7470,
#    17068,
#    602,
#    1401,
#    17069,
#    17070,
#    7,
#    52,
#    8644,
#    32,
#    10,
#    43,
#    14972,
#    17071,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    17072,
#    689],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 1671215.5087156338,
#   u'feature_2': 0.7431608336,
#   u'feature_3': 17,
#   u'feature_4': 1.1194091265,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  117: {u'attributes': [14460,
#    373,
#    19535,
#    5716,
#    375,
#    83,
#    378,
#    85,
#    42,
#    12049,
#    361],
#   u'availability': [],
#   u'duration': 90,
#   u'feature_1': 13060794.84127768,
#   u'feature_2': 0.7732243944,
#   u'feature_3': 0,
#   u'feature_4': 1.1004572841,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  118: {u'attributes': [20842,
#    20843,
#    1139,
#    1718,
#    7,
#    1721,
#    123,
#    42,
#    43,
#    170,
#    33,
#    17,
#    20,
#    302],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 37561120.637258165,
#   u'feature_2': 0.741832907,
#   u'feature_3': 7,
#   u'feature_4': 1.1175823742,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  119: {u'attributes': [7087, 1054, 7461, 1894, 7, 2757, 2758, 43, 489, 25],
#   u'availability': [],
#   u'duration': 100,
#   u'feature_1': 39335126.45349243,
#   u'feature_2': 0.6773504396,
#   u'feature_3': 1,
#   u'feature_4': 1.1386044027,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  120: {u'attributes': [16738,
#    13697,
#    1066,
#    1089,
#    7,
#    5318,
#    308,
#    54,
#    170,
#    33,
#    17,
#    20,
#    25],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 110,
#   u'feature_1': 36764165.87817783,
#   u'feature_2': 0.7360206399,
#   u'feature_3': 11,
#   u'feature_4': 1.1386044027,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  121: {u'attributes': [1121,
#    172,
#    1122,
#    1123,
#    7,
#    52,
#    1124,
#    123,
#    42,
#    175,
#    131,
#    33,
#    17,
#    164,
#    25],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 38736472.31346539,
#   u'feature_2': 0.6810516408,
#   u'feature_3': 6,
#   u'feature_4': 1.140272879,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  122: {u'attributes': [7912,
#    1583,
#    8068,
#    8069,
#    804,
#    7,
#    8070,
#    8071,
#    31,
#    42,
#    54,
#    17,
#    18,
#    20,
#    388,
#    7283,
#    403,
#    4981],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 6344580.984238636,
#   u'feature_2': 0.7703706452,
#   u'feature_3': 6,
#   u'feature_4': 1.1082255103,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  123: {u'attributes': [33434,
#    33435,
#    33436,
#    33437,
#    270,
#    33438,
#    123,
#    175,
#    14,
#    15,
#    32811,
#    25],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 40,
#   u'feature_1': 43046135.99053438,
#   u'feature_2': 0.6554293519,
#   u'feature_3': 9,
#   u'feature_4': 1.1386044027,
#   u'feature_5': 0.6547073468,
#   u'type': u'series'},
#  124: {u'attributes': [2570,
#    2571,
#    3560,
#    6505,
#    2960,
#    7,
#    3091,
#    1492,
#    17,
#    18,
#    20,
#    388,
#    4471,
#    197,
#    25],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 80,
#   u'feature_1': 21637977.59718211,
#   u'feature_2': 0.7024856449,
#   u'feature_3': 5,
#   u'feature_4': 1.1352308688,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  125: {u'attributes': [16893,
#    18462,
#    18463,
#    18464,
#    396,
#    113,
#    14031,
#    3771,
#    4861],
#   u'availability': [],
#   u'duration': 100,
#   u'feature_1': 34521809.0862566,
#   u'feature_2': 0.7844160523,
#   u'feature_3': 2,
#   u'feature_4': 1.0547431243,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  126: {u'attributes': [2860,
#    1517,
#    1373,
#    11071,
#    11072,
#    7,
#    8635,
#    8636,
#    43,
#    14,
#    15,
#    18,
#    19,
#    20,
#    21,
#    34,
#    44,
#    11073,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 19763043.792999398,
#   u'feature_2': 0.690396046,
#   u'feature_3': 10,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  127: {u'attributes': [5,
#    29445,
#    29446,
#    29447,
#    17600,
#    51,
#    29272,
#    54,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    29448,
#    29449,
#    29273,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 32258046.62990646,
#   u'feature_2': 0.6665585461,
#   u'feature_3': 11,
#   u'feature_4': 1.1386044027,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  128: {u'attributes': [1239,
#    2343,
#    8469,
#    1058,
#    19534,
#    7,
#    51,
#    10349,
#    123,
#    43,
#    17,
#    18,
#    19,
#    20,
#    32026,
#    32027,
#    165],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 9884585.371386299,
#   u'feature_2': 0.7369210328,
#   u'feature_3': 6,
#   u'feature_4': 1.1157410659,
#   u'feature_5': 0.5927161087,
# ...
#   u'feature_3': 10,
#   u'feature_4': 1.1212215513,
#   u'feature_5': 0.4496666915,
#   u'type': u'series'},
#  957: {u'attributes': [18092,
#    10320,
#    13475,
#    13435,
#    13460,
#    396,
#    18093,
#    3771,
#    14,
#    15,
#    19,
#    328,
#    272,
#    20,
#    16659,
#    10279],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 130,
#   u'feature_1': 30408933.293054778,
#   u'feature_2': 0.7591439814,
#   u'feature_3': 12,
#   u'feature_4': 1.0903647208,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  958: {u'attributes': [570,
#    788,
#    274,
#    789,
#    192,
#    83,
#    790,
#    10,
#    308,
#    42,
#    54,
#    175,
#    25],
#   u'availability': [],
#   u'duration': 90,
#   u'feature_1': 37379211.842428006,
#   u'feature_2': 0.6491567197,
#   u'feature_3': 0,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  959: {u'attributes': [1212,
#    1559,
#    1560,
#    1561,
#    1562,
#    7,
#    1563,
#    1564,
#    1565,
#    1492,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    22,
#    1566,
#    1567,
#    1568,
#    24],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 6414541.545249459,
#   u'feature_2': 0.7894949842,
#   u'feature_3': 18,
#   u'feature_4': 1.0710069277,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  960: {u'attributes': [621,
#    2271,
#    9336,
#    8684,
#    7,
#    9337,
#    42,
#    43,
#    17,
#    18,
#    19,
#    20,
#    7327,
#    7328,
#    171],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 5295172.569076285,
#   u'feature_2': 0.7400546,
#   u'feature_3': 6,
#   u'feature_4': 1.1120138405,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  961: {u'attributes': [13880,
#    13881,
#    13100,
#    5580,
#    2586,
#    13882,
#    7,
#    13883,
#    11,
#    43,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    44,
#    22,
#    8005,
#    1521,
#    1522,
#    24,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 6904265.472325223,
#   u'feature_2': 0.7088667501,
#   u'feature_3': 19,
#   u'feature_4': 1.1157410659,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  962: {u'attributes': [23692,
#    11109,
#    17512,
#    23693,
#    270,
#    4321,
#    42,
#    264,
#    265,
#    25],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 40300766.81358891,
#   u'feature_2': 0.6980000053,
#   u'feature_3': 4,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  963: {u'attributes': [8551, 16642, 16643, 16644, 3356, 7, 16645, 43, 16646],
#   u'availability': [],
#   u'duration': 90,
#   u'feature_1': 9590751.01514084,
#   u'feature_2': 0.6296473226,
#   u'feature_3': 0,
#   u'feature_4': 1.1265750641,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  964: {u'attributes': [16770, 16773, 7960, 7, 15899, 42, 910, 15902, 16776],
#   u'availability': [u'purchase'],
#   u'duration': 90,
#   u'feature_1': 13354629.197523138,
#   u'feature_2': 0.7505936251,
#   u'feature_3': 2,
#   u'feature_4': 0.8581432528,
#   u'feature_5': -1,
#   u'type': u'movie'},
#  965: {u'attributes': [8806,
#    28100,
#    368,
#    270,
#    51,
#    52,
#    28101,
#    1492,
#    14,
#    15,
#    16,
#    3274,
#    17,
#    20,
#    5216,
#    28102],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 70,
#   u'feature_1': 14932312.561955849,
#   u'feature_2': 0.6784118568,
#   u'feature_3': 10,
#   u'feature_4': 1.1230198714,
#   u'feature_5': 0.4496666915,
#   u'type': u'movie'},
#  966: {u'attributes': [769, 1352, 1353, 83, 1354, 10, 42, 43, 1355, 1356, 361],
#   u'availability': [],
#   u'duration': 90,
#   u'feature_1': 12039370.650519658,
#   u'feature_2': 0.7222341996,
#   u'feature_3': 0,
#   u'feature_4': 1.1157410659,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  967: {u'attributes': [6804,
#    822,
#    550,
#    2604,
#    39,
#    7,
#    29100,
#    31,
#    42,
#    54,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    29101,
#    29102,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 31502455.24279506,
#   u'feature_2': 0.6736103652,
#   u'feature_3': 9,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  968: {u'attributes': [12882,
#    12883,
#    10044,
#    12884,
#    12428,
#    270,
#    1163,
#    12885,
#    130,
#    31,
#    42,
#    14,
#    15,
#    17,
#    18,
#    19,
#    328,
#    272,
#    20,
#    56,
#    12886,
#    12887,
#    12888,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 26409281.542236283,
#   u'feature_2': 0.7641773546,
#   u'feature_3': 33,
#   u'feature_4': 1.1369237919,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  969: {u'attributes': [2264,
#    4954,
#    4955,
#    4956,
#    4957,
#    4958,
#    7,
#    4942,
#    31,
#    10,
#    54,
#    4959,
#    4960,
#    19,
#    20,
#    4961,
#    489],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 90,
#   u'feature_1': 1601254.9477048104,
#   u'feature_2': 0.7658394591,
#   u'feature_3': 4,
#   u'feature_4': 1.0664757439,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  970: {u'attributes': [2320,
#    1267,
#    3678,
#    3679,
#    3680,
#    7,
#    3681,
#    1134,
#    124,
#    19,
#    20,
#    3682],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 120,
#   u'feature_1': 7435965.736007481,
#   u'feature_2': 0.7859865299,
#   u'feature_3': 3,
#   u'feature_4': 1.1157410659,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  971: {u'attributes': [4160,
#    7246,
#    2551,
#    1183,
#    2313,
#    7,
#    5318,
#    32,
#    9,
#    54,
#    43,
#    20,
#    388,
#    5320,
#    197],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 6316596.759834306,
#   u'feature_2': 0.6725345178,
#   u'feature_3': 4,
#   u'feature_4': 1.1212215513,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  972: {u'attributes': [23651,
#    7256,
#    23748,
#    336,
#    1359,
#    42,
#    14,
#    15,
#    19,
#    20,
#    55,
#    23749,
#    23750,
#    361,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 15338456.129081966,
#   u'feature_2': 0.6514504811,
#   u'feature_3': 6,
#   u'feature_4': 1.1283323575,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  973: {u'attributes': [23660,
#    2259,
#    4350,
#    10394,
#    7033,
#    521,
#    7,
#    51,
#    52,
#    23661,
#    123,
#    43,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    23662,
#    23663],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 8821184.844021782,
#   u'feature_2': 0.7351179645,
#   u'feature_3': 9,
#   u'feature_4': 1.1194091265,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  974: {u'attributes': [1488,
#    1114,
#    17082,
#    3755,
#    17083,
#    821,
#    1538,
#    3938,
#    17084,
#    17085,
#    7316,
#    7,
#    17086,
#    42,
#    43,
#    17087,
#    17088,
#    11089,
#    17,
#    19,
#    20,
#    151,
#    17089,
#    14107,
#    489],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 80,
#   u'feature_1': 1601254.9477048104,
#   u'feature_2': 0.5267968757,
#   u'feature_3': 6,
#   u'feature_4': 1.1248043047,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  975: {u'attributes': [6622,
#    51,
#    6623,
#    1134,
#    14,
#    15,
#    1135,
#    17,
#    18,
#    19,
#    20,
#    1904,
#    3031,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 50,
#   u'feature_1': 25973670.327699218,
#   u'feature_2': 0.6929487826,
#   u'feature_3': 16,
#   u'feature_4': 1.1335254517,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  976: {u'attributes': [16893,
#    396,
#    18566,
#    3771,
#    14,
#    15,
#    3273,
#    16,
#    3274,
#    3275,
#    18567,
#    5048],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 10,
#   u'feature_1': 5491062.139906591,
#   u'feature_2': 0.7744404636,
#   u'feature_3': 11,
#   u'feature_4': 1.0710069277,
#   u'feature_5': 0.0,
#   u'type': u'movie'},
#  977: {u'attributes': [2653,
#    22565,
#    51,
#    22566,
#    42,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    55,
#    22567,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 100,
#   u'feature_1': 15324999.08561494,
#   u'feature_2': 0.7282739634,
#   u'feature_3': 9,
#   u'feature_4': 1.1318073548,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  978: {u'attributes': [24843,
#    24834,
#    24835,
#    24844,
#    24845,
#    270,
#    24839,
#    42,
#    14,
#    15,
#    17,
#    18,
#    19,
#    328,
#    272,
#    20,
#    24840,
#    24841,
#    24846,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 80,
#   u'feature_1': 29397187.465740483,
#   u'feature_2': 0.7049534665,
#   u'feature_3': 13,
#   u'feature_4': 1.1369237919,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  979: {u'attributes': [144,
#    1199,
#    679,
#    9097,
#    1249,
#    7,
#    51,
#    52,
#    1198,
#    42,
#    138,
#    17,
#    18,
#    19,
#    20,
#    8212],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 110,
#   u'feature_1': 9212963.985682394,
#   u'feature_2': 0.7641773546,
#   u'feature_3': 7,
#   u'feature_4': 1.1101274384,
#   u'feature_5': 0.6804096966,
#   u'type': u'movie'},
#  980: {u'attributes': [33611, 33612, 33613, 33614, 270, 33615, 175],
#   u'availability': [],
#   u'duration': 40,
#   u'feature_1': 39084459.382848084,
#   u'feature_2': 0.6380549192,
#   u'feature_3': 0,
#   u'feature_4': 1.140272879,
#   u'feature_5': 0.6547073468,
#   u'type': u'series'},
#  981: {u'attributes': [32073,
#    32074,
#    32075,
#    15435,
#    7,
#    32076,
#    32077,
#    32078,
#    1134,
#    14,
#    15,
#    1135,
#    11867,
#    25],
#   u'availability': [u'subscription'],
#   u'duration': 40,
#   u'feature_1': 41311255.61804541,
#   u'feature_2': 0.775652394,
#   u'feature_3': 8,
#   u'feature_4': 1.1335254517,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  982: {u'attributes': [22382,
#    22383,
#    7138,
#    22384,
#    7,
#    22385,
#    130,
#    42,
#    17,
#    19,
#    20,
#    151,
#    22386,
#    188],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 120,
#   u'feature_1': 14933451.688312678,
#   u'feature_2': 0.7531803573,
#   u'feature_3': 4,
#   u'feature_4': 1.0007587113,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  983: {u'attributes': [33439,
#    33440,
#    33441,
#    33442,
#    270,
#    20853,
#    33443,
#    123,
#    175,
#    14,
#    15,
#    32811,
#    25],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 40,
#   u'feature_1': 43046135.99053438,
#   u'feature_2': 0.6826261691,
#   u'feature_3': 8,
#   u'feature_4': 1.1352308688,
#   u'feature_5': 0.5927161087,
#   u'type': u'series'},
#  984: {u'attributes': [1131,
#    13393,
#    3127,
#    2898,
#    1119,
#    2664,
#    83,
#    51,
#    3664,
#    42,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    25319,
#    361,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 120,
#   u'feature_1': 25555764.317361668,
#   u'feature_2': 0.7231700877,
#   u'feature_3': 9,
#   u'feature_4': 1.1352308688,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  985: {u'attributes': [1219,
#    27818,
#    16950,
#    22745,
#    2546,
#    7,
#    25736,
#    123,
#    42,
#    43,
#    14,
#    15,
#    239,
#    20,
#    21,
#    27819],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 12039370.650519658,
#   u'feature_2': 0.7351179645,
#   u'feature_3': 7,
#   u'feature_4': 1.1082255103,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  986: {u'attributes': [881,
#    3825,
#    3090,
#    8943,
#    179,
#    7,
#    27230,
#    42,
#    170,
#    33,
#    17,
#    20,
#    8660,
#    3119,
#    27234],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 120,
#   u'feature_1': 6610431.116079764,
#   u'feature_2': 0.7703706452,
#   u'feature_3': 7,
#   u'feature_4': 1.1230198714,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  987: {u'attributes': [21946,
#    396,
#    21947,
#    9744,
#    1492,
#    14,
#    15,
#    3273,
#    16,
#    9732,
#    9733],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 10,
#   u'feature_1': 36000763.362040415,
#   u'feature_2': 0.7360206399,
#   u'feature_3': 11,
#   u'feature_4': 1.0183177601,
#   u'feature_5': 0.4496666915,
#   u'type': u'movie'},
#  988: {u'attributes': [27341, 7, 27342, 1241, 25],
#   u'availability': [],
#   u'duration': 40,
#   u'feature_1': 21370088.73038134,
#   u'feature_2': 0.717517505,
#   u'feature_3': 0,
#   u'feature_4': 1.1300763881,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  989: {u'attributes': [21935,
#    21936,
#    21937,
#    18403,
#    396,
#    21855,
#    21922,
#    1492,
#    14,
#    15,
#    3273,
#    16,
#    6478,
#    6479,
#    3277],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 20,
#   u'feature_1': 36000763.362040415,
#   u'feature_2': 0.7732243944,
#   u'feature_3': 11,
#   u'feature_4': 0.9817548875,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  990: {u'attributes': [2754, 234, 2692, 2803, 2301, 7, 2804, 42, 43, 2805],
#   u'availability': [],
#   u'duration': 80,
#   u'feature_1': 13158739.626692833,
#   u'feature_2': 0.6883405989,
#   u'feature_3': 0,
#   u'feature_4': 1.1212215513,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  991: {u'attributes': [12629,
#    6812,
#    14003,
#    23583,
#    7,
#    23580,
#    42,
#    19499,
#    23584,
#    197],
#   u'availability': [],
#   u'duration': 110,
#   u'feature_1': 6400549.433047295,
#   u'feature_2': 0.7840223483,
#   u'feature_3': 1,
#   u'feature_4': 0.9914520991,
#   u'feature_5': 0.5927161087,
#   u'type': u'movie'},
#  992: {u'attributes': [716,
#    3008,
#    7430,
#    2491,
#    17159,
#    7,
#    826,
#    42,
#    54,
#    1383,
#    170,
#    33,
#    17,
#    20,
#    7646,
#    1551,
#    302],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 150,
#   u'feature_1': 14501998.430729207,
#   u'feature_2': 0.7462402062,
#   u'feature_3': 7,
#   u'feature_4': 1.1043740383,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  993: {u'attributes': [35552, 35553, 1163, 35554, 1492, 14, 15, 3273, 25],
#   u'availability': [u'purchase', u'subscription'],
#   u'duration': 0,
#   u'feature_1': 38412468.9227957,
#   u'feature_2': 0.6197891088,
#   u'feature_3': 9,
#   u'feature_4': 1.1230198714,
#   u'feature_5': 0.4496666915,
#   u'type': u'series'},
#  994: {u'attributes': [318,
#    134,
#    727,
#    4537,
#    5268,
#    7,
#    51,
#    4291,
#    42,
#    54,
#    17,
#    19,
#    20,
#    151,
#    12818,
#    25],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 14264116.490663841,
#   u'feature_2': 0.776860214,
#   u'feature_3': 5,
#   u'feature_4': 1.1004572841,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  995: {u'attributes': [1277,
#    2834,
#    5977,
#    4937,
#    26799,
#    7,
#    10,
#    42,
#    43,
#    14,
#    15,
#    17,
#    18,
#    19,
#    20,
#    21,
#    25939,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 31952530.15553814,
#   u'feature_2': 0.6810516408,
#   u'feature_3': 10,
#   u'feature_4': 1.1248043047,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  996: {u'attributes': [5795,
#    22095,
#    845,
#    277,
#    9023,
#    342,
#    7,
#    4564,
#    42,
#    54,
#    17,
#    18,
#    19,
#    20,
#    11858,
#    617,
#    22096],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 100,
#   u'feature_1': 9884585.371386299,
#   u'feature_2': 0.7475518292,
#   u'feature_3': 6,
#   u'feature_4': 1.1120138405,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  997: {u'attributes': [15759, 83, 15760, 1134, 25],
#   u'availability': [],
#   u'duration': 0,
#   u'feature_1': 32644671.84829353,
#   u'feature_2': 0.6929487826,
#   u'feature_3': 0,
#   u'feature_4': 1.1352308688,
#   u'feature_5': -1,
#   u'type': u'movie'},
#  998: {u'attributes': [4622,
#    716,
#    7338,
#    7339,
#    7340,
#    7,
#    51,
#    4912,
#    31,
#    43,
#    19,
#    20,
#    7341,
#    4915],
#   u'availability': [u'purchase', u'rent'],
#   u'duration': 80,
#   u'feature_1': 12641031.47521274,
#   u'feature_2': 0.7093529007,
#   u'feature_3': 4,
#   u'feature_4': 1.1194091265,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  999: {u'attributes': [14214,
#    5017,
#    3497,
#    23442,
#    192,
#    16528,
#    31,
#    42,
#    14,
#    15,
#    131,
#    17,
#    18,
#    19,
#    21,
#    25],
#   u'availability': [u'purchase', u'rent', u'subscription'],
#   u'duration': 90,
#   u'feature_1': 41269081.707632355,
#   u'feature_2': 0.6643603587,
#   u'feature_3': 15,
#   u'feature_4': 1.1419293948,
#   u'feature_5': 0.6547073468,
#   u'type': u'movie'},
#  ...}

# %%
len(catalogue)
# Out:
# 10200

# %%
pprint(catalogue[100])
# Out:
# {'attributes': [18441,
#                 16300,
#                 16580,
#                 18770,
#                 18771,
#                 18643,
#                 396,
#                 18772,
#                 3771,
#                 18773,
#                 910,
#                 18774,
#                 16364,
#                 3277],
#  'availability': ['purchase', 'rent'],
#  'duration': 80,
#  'feature_1': 6064738.740195342,
#  'feature_2': 0.752750538,
#  'feature_3': 4,
#  'feature_4': 0.9537104605,
#  'feature_5': 0.0,
#  'type': 'movie'}

# %% [markdown]
#  - `attributes` — мешок атрибутов
#  - `availability` — доступность (может содержать значения `purchase`, `rent` и `subscription`)
#  - `duration` — длительность в минутах, округлённая до десятков (продолжительность серии для сериалов и многосерийных фильмов)
#  - `feature_1..5` — пять анонимизированных вещественных и порядковых признаков
#  - `type` — принимает значения `movie`, `multipart_movie` или `series`

# %% [markdown]
# ---

# %% [markdown]
# `test_users.json` содержит список пользователей, для которых необходимо построить предсказание

# %%
with open(os.path.join(DATA_PATH, 'test_users.json'), 'r') as f:
    test_users = set(json.load(f)['users'])

# %% [markdown]
# ---

# %% [markdown]
# `transactions.csv` — список всех транзакций за определённый период времени

# %%
# %%time
transactions = pd.read_csv(
    os.path.join(DATA_PATH, 'transactions.csv'),
    dtype={
        'element_uid': np.uint16,
        'user_uid': np.uint32,
        'consumption_mode': 'category',
        'ts': np.float64,
        'watched_time': np.uint64,
        'device_type': np.uint8,
        'device_manufacturer': np.uint8
    }
)
# Out:
# CPU times: user 3.87 s, sys: 221 ms, total: 4.09 s
# Wall time: 4.15 s

# %%
transactions.head(3)
# Out:
#    element_uid  user_uid consumption_mode            ts  watched_time  \
# 0         3336      5177                S  4.430518e+07          4282
# 1          481    593316                S  4.430518e+07          2989
# 2         4128    262355                S  4.430518e+07           833
#
#    device_type  device_manufacturer
# 0            0                   50
# 1            0                   11
# 2            0                   50

# %%
print('device type len: {}'.format(len(transactions.device_type.unique())))
# Out:
# device type len: 7

# %%
print('device manufacturer len: {}'.format(len(transactions.device_manufacturer.unique())))
# Out:
# device manufacturer len: 100

# %% [markdown]
#  - `element_uid` — идентификатор элемента
#  - `user_uid` — идентификатор пользователя
#  - `consumption_mode` — тип потребления (`P` — покупка, `R` — аренда, `S` — просмотр по подписке)
#  - `ts` — время совершения транзакции или начала просмотра в случае просмотра по подписке
#  - `watched_time` — число просмотренных по транзакции секунд
#  - `device_type` — анонимизированный тип устройства, с которого была совершена транзакция или начат просмотр
#  - `device_manufacturer` — анонимизированный производитель устройства, с которого была совершена транзакция или начат просмотр

# %% [markdown]
# ---

# %% [markdown]
# `ratings.csv` содержит информацию о поставленных пользователями оценках

# %%
# %%time
ratings = pd.read_csv(
    os.path.join(DATA_PATH, 'ratings.csv'),
    dtype={
        'element_uid': np.uint16,
        'user_uid': np.uint32,
        'ts': np.float64,
        'rating': np.uint8
    }
)
# Out:
# CPU times: user 143 ms, sys: 12.5 ms, total: 155 ms
# Wall time: 173 ms

# %%
ratings.head(3)
# Out:
#    user_uid  element_uid  rating            ts
# 0    571252         1364      10  4.430517e+07
# 1     63140         3037      10  4.430514e+07
# 2    443817         4363       8  4.430514e+07

# %% [markdown]
#  - `rating` — поставленный пользователем рейтинг (от `0` до `10`)

# %% [markdown]
# ---

# %% [markdown]
# `bookmarks.csv` содержит информацию об элементах, добавленных пользователями в список «Избранное»

# %%
# %%time

bookmarks = pd.read_csv(
    os.path.join(DATA_PATH, 'bookmarks.csv'),
    dtype={
        'element_uid': np.uint16,
        'user_uid': np.uint32,
        'ts': np.float64
    }
)
# Out:
# CPU times: user 261 ms, sys: 15.4 ms, total: 277 ms
# Wall time: 281 ms

# %%
bookmarks.head(3)
# Out:
#    user_uid  element_uid            ts
# 0    301135         7185  4.430516e+07
# 1    301135         4083  4.430516e+07
# 2    301135        10158  4.430516e+07

# %% [markdown]
# ### Решение

# %% [markdown]
# Для начала построим список элементов, которые тестовые пользователи уже купили или посмотрели по подписке: они не смогут купить их второй раз, а просмотр по подписке второй раз маловероятен, поэтому мы захотим отфильтровать такие элементы из финального ответа.
#
# Точно так же можно поступить и с рейтингами и добавлениями в избранное, если это будет казаться правильным.

# %%
from collections import defaultdict

filtered_elements = defaultdict(set)

for user_uid, element_uid in tqdm.tqdm(transactions.loc[:, ['user_uid', 'element_uid']].values):
    if user_uid not in test_users:
        continue
    filtered_elements[user_uid].add(element_uid)
# Out:
# 100%|██████████| 9643012/9643012 [00:14<00:00, 665937.27it/s]

# %% [markdown]
# ---

# %% [markdown]
# Для примера мы воспользуемся методом K ближайших соседей, реализованным в библиотеке `implicit`. В качестве данных используем только информацию о рейтингах.
#
# Необходимо построить разреженную матрицу, где строкам будут соответствовать элементы, столбцам — пользователи, а на пересечении пользователя и элемента будет находиться количественная оценка степени их взаимодействия, если таковое имело место.
#
# Не забудем добавить `1` к рейтингу, чтобы избежать деления на ноль во время вычисления `tf-idf`.

# %%
ratings['user_uid'] = ratings['user_uid'].astype('category')
ratings['element_uid'] = ratings['element_uid'].astype('category')

ratings_matrix = sp.coo_matrix(
    (ratings['rating'].astype(np.float32) + 1,
        (
            ratings['element_uid'].cat.codes.copy(),
            ratings['user_uid'].cat.codes.copy()
        )
    )
)

ratings_matrix = ratings_matrix.tocsr()

# %%
sparsity = ratings_matrix.nnz / (ratings_matrix.shape[0] * ratings_matrix.shape[1])
print('Sparsity: %.6f' % sparsity)
# Out:
# Sparsity: 0.000558

# %% [markdown]
# Обучить модель крайне просто.

# %%
from implicit.nearest_neighbours import TFIDFRecommender

model = TFIDFRecommender()
model.fit(ratings_matrix)
# Out:
# 100%|██████████| 7519/7519 [00:00<00:00, 17852.46it/s]

# %% [markdown]
# ---

# %%
ratings_matrix_T = ratings_matrix.T.tocsr()

# %% [markdown]
# Отображения из оригинальной категории во внутреннюю пригодится нам в дальнейшем.

# %%
user_uid_to_cat = dict(zip(
    ratings['user_uid'].cat.categories,
    range(len(ratings['user_uid'].cat.categories))
))

# %%
element_uid_to_cat = dict(zip(
    ratings['element_uid'].cat.categories,
    range(len(ratings['element_uid'].cat.categories))
))

# %%
filtered_elements_cat = {k: [element_uid_to_cat.get(x, None) for x in v] for k, v in filtered_elements.items()}

# %% [markdown]
# ---

# %% [markdown]
# В метод `model.recommend` мы передаём идентификатор пользователя, который получаем обратным преобразованием из категории, транспонированную матрицу взаимодействий, число необходимых рекомендаций и список элементов, которые мы договорились фильтровать из ответа.
#
# Возвращает метод список пар (`element_cat`, `score`), отсортированный по вторым элементам. Из него необходимо достать все первые элементы пар и из категории преобразовать их к `element_uid`.

# %% [markdown]
# **Важно:** Не все тестовые пользователи есть в `ratings.csv` и не все из них есть в `transactions.csv`. Используя только один источник данных мы не можем построить полное предсказание. Такой ответ с неполным числом пользователей бдет принят системой, но при вычислении средней метрики метрика для отсутствующих пользователей будет принята равной нулю.

# %%
result = {}

for user_uid in tqdm.tqdm(test_users):
    # transform user_uid to model's internal user category
    try:
        user_cat = user_uid_to_cat[user_uid]
    except LookupError:
        continue
    
    # perform inference
    recs = model.recommend(
        user_cat,
        ratings_matrix_T,
        N=20,
        filter_already_liked_items=True,
        filter_items=filtered_elements_cat.get(user_uid, set())
    )
    
    # drop scores and transform model's internal elelemnt category to element_uid for every prediction
    # also convert np.uint64 to int so it could be json serialized later
    result[user_uid] = [int(ratings['element_uid'].cat.categories[i]) for i, _ in recs]
# Out:
# 100%|██████████| 50000/50000 [00:01<00:00, 27307.04it/s]

# %%
len(result)
# Out:
# 13251

# %% [markdown]
# Используя только информацию о рейтингах мы смогли построить предсказание для `13251` из `50000` тестовых пользователей. Ровно в таком виде ответы и стоит сохранить для отправки.

# %%
with open('answer.json', 'w') as f:
    json.dump(result, f)
